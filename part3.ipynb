# %%
import random
import matplotlib.pyplot as plt

# %%
rv1 = random.uniform(100, 500)
rv2 = random.normalvariate(100, 500)
rv3 = random.expovariate(100, 500)
rv4 = random.gammavariate(100, 500)

# %%
plt.subplots(2,2, figsize = (20,7))
plt.
# Out:
# (<Figure size 2000x700 with 4 Axes>,
#  array([[<Axes: >, <Axes: >],
#         [<Axes: >, <Axes: >]], dtype=object))
